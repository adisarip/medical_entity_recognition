# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14042470523181714244
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 16363155259459063512
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 17643574356602653192
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 3480158208
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 535193609772053633
# physical_device_desc: "device: 0, name: GeForce GTX 960M, pci bus id: 0000:01:00.0, compute capability: 5.0"
# ]

# %%
from keras import backend as K
K.tensorflow_backend._get_available_gpus()
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W1021 22:47:40.302240 140402059106048 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W1021 22:47:40.303132 140402059106048 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W1021 22:47:40.303763 140402059106048 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W1021 22:47:40.309170 140402059106048 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# ['/job:localhost/replica:0/task:0/device:GPU:0']

# %%
import keras
import tensorflow as tf

config = tf.ConfigProto( device_count = {'GPU': 1 , 'CPU': 56} ) 
sess = tf.Session(config=config) 
keras.backend.set_session(sess)

# %%
# A class to get the sentences from the dataset
class SentenceGetter(object):

    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
        aggregate_function = lambda s : [(w, t)
                                         for w, t in zip(s["Word"].values.tolist(),
                                                         s["Tag"].values.tolist())]
        self.grouped = self.data.groupby("Sentence #").apply(aggregate_function)
        self.sentences = [s for s in self.grouped]

    def getNext(self):
        try:
            s = self.grouped["{}".format(self.n_sent)]
            self.n_sent += 1
            return s
        except:
            print("Exception")
            self.empty = True
            return None

# %%
import pandas as pd
import numpy as np

# read the annotated dataset from kaggle
all_files = ["CADEC.csv","PubMed.csv","Micromed.csv"]
df_from_each_file = (pd.read_csv(f) for f in all_files)
data   = pd.concat(df_from_each_file, axis=0, ignore_index=True)
display(data.tail(10))

l_words = list(set(data["Word"].values))
n_words = len(l_words)

l_tags = list(set(data["Tag"].values))
n_tags = len(l_tags)

sentence_getter = SentenceGetter(data)
l_sentences = sentence_getter.sentences

# Prepare the data
n_max_seq_size = 45 
d_words_to_index = {word: index + 1 for index, word in enumerate(l_words)}
d_tags_to_index = {tag: index for index, tag in enumerate(l_tags)}
# Out:
#        Document ID  Sentence #         Word        Tag
# 165640  4.7174e+17        8925  painkillers     B-Drug
# 165641  4.7174e+17        8925            ;          O
# 165642  4.7174e+17        8925       before          O
# 165643  4.7174e+17        8925           or          O
# 165644  4.7174e+17        8925        after          O
# 165645  4.7174e+17        8925          the          O
# 165646  4.7174e+17        8925         pain  B-Symptom
# 165647  4.7174e+17        8925           is          O
# 165648  4.7174e+17        8925    inflicted          O
# 165649  4.7174e+17        8925            ?          O

# %%
# preparing training and test data sets
import warnings
warnings.filterwarnings('ignore')
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

X = [[d_words_to_index[word[0]] for word in sentence] for sentence in l_sentences]
X = pad_sequences(maxlen=n_max_seq_size, sequences=X, padding="post", value=n_words-1)

y = [[d_tags_to_index[word[1]] for word in sentence] for sentence in l_sentences]
y = pad_sequences(maxlen=n_max_seq_size, sequences=y, padding="post", value=d_tags_to_index["O"])

# changing the y-labels to categorical for training purposes
y = [to_categorical(idx, num_classes=n_tags) for idx in y]

# Split in Training and Test sets
X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.1)

# %%
# Now fitting a LSTM-CRF network with an embedding layer
from keras.models import Model, Input
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
from keras_contrib.layers import CRF

model_input = Input(shape=(n_max_seq_size,))

model = Embedding(input_dim = n_words + 1,
                  output_dim = 20,
                 input_length = n_max_seq_size,
                  mask_zero = True)(model_input)  # 20-dim embedding#

model = Bidirectional(LSTM(units=50,
                           return_sequences=True,
                           recurrent_dropout=0.1))(model)     # variational biLSTM

model = TimeDistributed(Dense(50, activation="relu"))(model)  # a dense layer as suggested by neuralNer

crf = CRF(n_tags) # CRF layer
out = crf(model)  # output

model = Model(model_input, out)
model.compile(optimizer="rmsprop", loss=crf.loss_function, metrics=[crf.accuracy])
model.summary()

history = model.fit(X_tr,
                    np.array(y_tr),
                    batch_size=512,
                    epochs=60,
                    validation_split=0.1,
                    verbose=1)
hist = pd.DataFrame(history.history)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 45)                0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 45, 20)            241840
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 45, 100)           28400
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 45, 50)            5050
# _________________________________________________________________
# crf_2 (CRF)                  (None, 45, 11)            704
# =================================================================
# Total params: 275,994
# Trainable params: 275,994
# Non-trainable params: 0
# _________________________________________________________________
# Train on 7229 samples, validate on 804 samples
# Epoch 1/60
# 7229/7229 [==============================] - 7s 909us/step - loss: 1.1244 - crf_viterbi_accuracy: 0.8785 - val_loss: 0.3628 - val_crf_viterbi_accuracy: 0.9359
# Epoch 2/60
# 7229/7229 [==============================] - 2s 337us/step - loss: 0.3201 - crf_viterbi_accuracy: 0.9415 - val_loss: 0.3194 - val_crf_viterbi_accuracy: 0.9359
# Epoch 3/60
# 7229/7229 [==============================] - 2s 325us/step - loss: 0.2903 - crf_viterbi_accuracy: 0.9415 - val_loss: 0.3028 - val_crf_viterbi_accuracy: 0.9359
# Epoch 4/60
# 7229/7229 [==============================] - 2s 331us/step - loss: 0.2752 - crf_viterbi_accuracy: 0.9415 - val_loss: 0.2996 - val_crf_viterbi_accuracy: 0.9359
# Epoch 5/60
# 7229/7229 [==============================] - 2s 329us/step - loss: 0.2621 - crf_viterbi_accuracy: 0.9415 - val_loss: 0.2798 - val_crf_viterbi_accuracy: 0.9359
# Epoch 6/60
# 7229/7229 [==============================] - 2s 318us/step - loss: 0.2482 - crf_viterbi_accuracy: 0.9415 - val_loss: 0.2655 - val_crf_viterbi_accuracy: 0.9359
# Epoch 7/60
# 7229/7229 [==============================] - 2s 323us/step - loss: 0.2317 - crf_viterbi_accuracy: 0.9416 - val_loss: 0.2488 - val_crf_viterbi_accuracy: 0.9362
# Epoch 8/60
# 7229/7229 [==============================] - 2s 316us/step - loss: 0.2151 - crf_viterbi_accuracy: 0.9434 - val_loss: 0.2328 - val_crf_viterbi_accuracy: 0.9405
# Epoch 9/60
# 7229/7229 [==============================] - 2s 319us/step - loss: 0.1996 - crf_viterbi_accuracy: 0.9469 - val_loss: 0.2216 - val_crf_viterbi_accuracy: 0.9407
# Epoch 10/60
# 7229/7229 [==============================] - 2s 316us/step - loss: 0.1858 - crf_viterbi_accuracy: 0.9487 - val_loss: 0.2074 - val_crf_viterbi_accuracy: 0.9436
# Epoch 11/60
# 7229/7229 [==============================] - 2s 327us/step - loss: 0.1732 - crf_viterbi_accuracy: 0.9503 - val_loss: 0.1980 - val_crf_viterbi_accuracy: 0.9427
# Epoch 12/60
# 7229/7229 [==============================] - 2s 324us/step - loss: 0.1616 - crf_viterbi_accuracy: 0.9516 - val_loss: 0.1929 - val_crf_viterbi_accuracy: 0.9444
# Epoch 13/60
# 7229/7229 [==============================] - 2s 327us/step - loss: 0.1526 - crf_viterbi_accuracy: 0.9532 - val_loss: 0.1868 - val_crf_viterbi_accuracy: 0.9436
# Epoch 14/60
# 7229/7229 [==============================] - 2s 319us/step - loss: 0.1448 - crf_viterbi_accuracy: 0.9553 - val_loss: 0.1776 - val_crf_viterbi_accuracy: 0.9469
# Epoch 15/60
# 7229/7229 [==============================] - 2s 325us/step - loss: 0.1383 - crf_viterbi_accuracy: 0.9571 - val_loss: 0.1752 - val_crf_viterbi_accuracy: 0.9467
# Epoch 16/60
# 7229/7229 [==============================] - 2s 323us/step - loss: 0.1323 - crf_viterbi_accuracy: 0.9582 - val_loss: 0.1702 - val_crf_viterbi_accuracy: 0.9484
# Epoch 17/60
# 7229/7229 [==============================] - 2s 316us/step - loss: 0.1268 - crf_viterbi_accuracy: 0.9597 - val_loss: 0.1679 - val_crf_viterbi_accuracy: 0.9504
# Epoch 18/60
# 7229/7229 [==============================] - 2s 318us/step - loss: 0.1205 - crf_viterbi_accuracy: 0.9611 - val_loss: 0.1657 - val_crf_viterbi_accuracy: 0.9497
# Epoch 19/60
# 7229/7229 [==============================] - 2s 320us/step - loss: 0.1169 - crf_viterbi_accuracy: 0.9622 - val_loss: 0.1647 - val_crf_viterbi_accuracy: 0.9513
# Epoch 20/60
# 7229/7229 [==============================] - 2s 330us/step - loss: 0.1125 - crf_viterbi_accuracy: 0.9633 - val_loss: 0.1579 - val_crf_viterbi_accuracy: 0.9528
# Epoch 21/60
# 7229/7229 [==============================] - 2s 333us/step - loss: 0.1082 - crf_viterbi_accuracy: 0.9647 - val_loss: 0.1585 - val_crf_viterbi_accuracy: 0.9537
# Epoch 22/60
# 7229/7229 [==============================] - 3s 353us/step - loss: 0.1039 - crf_viterbi_accuracy: 0.9661 - val_loss: 0.1579 - val_crf_viterbi_accuracy: 0.9542
# Epoch 23/60
# 7229/7229 [==============================] - 3s 362us/step - loss: 0.1006 - crf_viterbi_accuracy: 0.9669 - val_loss: 0.1525 - val_crf_viterbi_accuracy: 0.9541
# Epoch 24/60
# 7229/7229 [==============================] - 2s 321us/step - loss: 0.0968 - crf_viterbi_accuracy: 0.9679 - val_loss: 0.1554 - val_crf_viterbi_accuracy: 0.9557
# Epoch 25/60
# 7229/7229 [==============================] - 2s 317us/step - loss: 0.0935 - crf_viterbi_accuracy: 0.9689 - val_loss: 0.1594 - val_crf_viterbi_accuracy: 0.9558
# Epoch 26/60
# 7229/7229 [==============================] - 2s 329us/step - loss: 0.0913 - crf_viterbi_accuracy: 0.9698 - val_loss: 0.1562 - val_crf_viterbi_accuracy: 0.9566
# Epoch 27/60
# 7229/7229 [==============================] - 2s 343us/step - loss: 0.0876 - crf_viterbi_accuracy: 0.9707 - val_loss: 0.1582 - val_crf_viterbi_accuracy: 0.9569
# Epoch 28/60
# 7229/7229 [==============================] - 2s 323us/step - loss: 0.0842 - crf_viterbi_accuracy: 0.9718 - val_loss: 0.1424 - val_crf_viterbi_accuracy: 0.9571
# Epoch 29/60
# 7229/7229 [==============================] - 2s 329us/step - loss: 0.0817 - crf_viterbi_accuracy: 0.9723 - val_loss: 0.1447 - val_crf_viterbi_accuracy: 0.9555
# Epoch 30/60
# 7229/7229 [==============================] - 3s 349us/step - loss: 0.0790 - crf_viterbi_accuracy: 0.9730 - val_loss: 0.1587 - val_crf_viterbi_accuracy: 0.9573
# Epoch 31/60
# 7229/7229 [==============================] - 2s 343us/step - loss: 0.0770 - crf_viterbi_accuracy: 0.9735 - val_loss: 0.1418 - val_crf_viterbi_accuracy: 0.9594
# Epoch 32/60
# 7229/7229 [==============================] - 2s 327us/step - loss: 0.0742 - crf_viterbi_accuracy: 0.9742 - val_loss: 0.1506 - val_crf_viterbi_accuracy: 0.9570
# Epoch 33/60
# 7229/7229 [==============================] - 2s 316us/step - loss: 0.0714 - crf_viterbi_accuracy: 0.9749 - val_loss: 0.1462 - val_crf_viterbi_accuracy: 0.9590
# Epoch 34/60
# 7229/7229 [==============================] - 2s 317us/step - loss: 0.0706 - crf_viterbi_accuracy: 0.9749 - val_loss: 0.1413 - val_crf_viterbi_accuracy: 0.9583
# Epoch 35/60
# 7229/7229 [==============================] - 2s 308us/step - loss: 0.0672 - crf_viterbi_accuracy: 0.9762 - val_loss: 0.1426 - val_crf_viterbi_accuracy: 0.9597
# Epoch 36/60
# 7229/7229 [==============================] - 2s 308us/step - loss: 0.0650 - crf_viterbi_accuracy: 0.9765 - val_loss: 0.1446 - val_crf_viterbi_accuracy: 0.9602
# Epoch 37/60
# 7229/7229 [==============================] - 2s 317us/step - loss: 0.0626 - crf_viterbi_accuracy: 0.9774 - val_loss: 0.1460 - val_crf_viterbi_accuracy: 0.9566
# Epoch 38/60
# 7229/7229 [==============================] - 2s 325us/step - loss: 0.0614 - crf_viterbi_accuracy: 0.9774 - val_loss: 0.1454 - val_crf_viterbi_accuracy: 0.9610
# Epoch 39/60
# 7229/7229 [==============================] - 3s 360us/step - loss: 0.0590 - crf_viterbi_accuracy: 0.9783 - val_loss: 0.1499 - val_crf_viterbi_accuracy: 0.9609
# Epoch 40/60
# 7229/7229 [==============================] - 2s 322us/step - loss: 0.0570 - crf_viterbi_accuracy: 0.9791 - val_loss: 0.1424 - val_crf_viterbi_accuracy: 0.9614
# Epoch 41/60
# 7229/7229 [==============================] - 2s 319us/step - loss: 0.0560 - crf_viterbi_accuracy: 0.9790 - val_loss: 0.1584 - val_crf_viterbi_accuracy: 0.9604
# Epoch 42/60
# 7229/7229 [==============================] - 2s 310us/step - loss: 0.0540 - crf_viterbi_accuracy: 0.9800 - val_loss: 0.1546 - val_crf_viterbi_accuracy: 0.9610
# Epoch 43/60
# 7229/7229 [==============================] - 2s 326us/step - loss: 0.0529 - crf_viterbi_accuracy: 0.9801 - val_loss: 0.1423 - val_crf_viterbi_accuracy: 0.9612
# Epoch 44/60
# 7229/7229 [==============================] - 3s 356us/step - loss: 0.0512 - crf_viterbi_accuracy: 0.9805 - val_loss: 0.1494 - val_crf_viterbi_accuracy: 0.9606
# Epoch 45/60
# 7229/7229 [==============================] - 3s 348us/step - loss: 0.0493 - crf_viterbi_accuracy: 0.9812 - val_loss: 0.1615 - val_crf_viterbi_accuracy: 0.9606
# Epoch 46/60
# 7229/7229 [==============================] - 3s 356us/step - loss: 0.0482 - crf_viterbi_accuracy: 0.9815 - val_loss: 0.1488 - val_crf_viterbi_accuracy: 0.9606
# Epoch 47/60
# 7229/7229 [==============================] - 3s 356us/step - loss: 0.0468 - crf_viterbi_accuracy: 0.9821 - val_loss: 0.1398 - val_crf_viterbi_accuracy: 0.9618
# Epoch 48/60
# 7229/7229 [==============================] - 3s 363us/step - loss: 0.0449 - crf_viterbi_accuracy: 0.9827 - val_loss: 0.1457 - val_crf_viterbi_accuracy: 0.9616
# Epoch 49/60
# 7229/7229 [==============================] - 3s 351us/step - loss: 0.0437 - crf_viterbi_accuracy: 0.9831 - val_loss: 0.1460 - val_crf_viterbi_accuracy: 0.9603
# Epoch 50/60
# 7229/7229 [==============================] - 3s 364us/step - loss: 0.0429 - crf_viterbi_accuracy: 0.9831 - val_loss: 0.1701 - val_crf_viterbi_accuracy: 0.9609
# Epoch 51/60
# 7229/7229 [==============================] - 3s 355us/step - loss: 0.0419 - crf_viterbi_accuracy: 0.9838 - val_loss: 0.1620 - val_crf_viterbi_accuracy: 0.9609
# Epoch 52/60
# 7229/7229 [==============================] - 2s 316us/step - loss: 0.0396 - crf_viterbi_accuracy: 0.9845 - val_loss: 0.1511 - val_crf_viterbi_accuracy: 0.9611
# Epoch 53/60
# 7229/7229 [==============================] - 3s 356us/step - loss: 0.0389 - crf_viterbi_accuracy: 0.9849 - val_loss: 0.1621 - val_crf_viterbi_accuracy: 0.9603
# Epoch 54/60
# 7229/7229 [==============================] - 3s 348us/step - loss: 0.0376 - crf_viterbi_accuracy: 0.9852 - val_loss: 0.1562 - val_crf_viterbi_accuracy: 0.9625
# Epoch 55/60
# 7229/7229 [==============================] - 2s 328us/step - loss: 0.0369 - crf_viterbi_accuracy: 0.9856 - val_loss: 0.1522 - val_crf_viterbi_accuracy: 0.9604
# Epoch 56/60
# 7229/7229 [==============================] - 2s 328us/step - loss: 0.0354 - crf_viterbi_accuracy: 0.9861 - val_loss: 0.1744 - val_crf_viterbi_accuracy: 0.9606
# Epoch 57/60
# 7229/7229 [==============================] - 2s 323us/step - loss: 0.0344 - crf_viterbi_accuracy: 0.9865 - val_loss: 0.1538 - val_crf_viterbi_accuracy: 0.9570
# Epoch 58/60
# 7229/7229 [==============================] - 2s 334us/step - loss: 0.0336 - crf_viterbi_accuracy: 0.9868 - val_loss: 0.1565 - val_crf_viterbi_accuracy: 0.9610
# Epoch 59/60
# 7229/7229 [==============================] - 2s 323us/step - loss: 0.0333 - crf_viterbi_accuracy: 0.9867 - val_loss: 0.1613 - val_crf_viterbi_accuracy: 0.9633
# Epoch 60/60
# 7229/7229 [==============================] - 2s 318us/step - loss: 0.0318 - crf_viterbi_accuracy: 0.9874 - val_loss: 0.1638 - val_crf_viterbi_accuracy: 0.9617

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.figure(figsize=(10,10))
plt.plot(hist["crf_viterbi_accuracy"])
plt.plot(hist["val_crf_viterbi_accuracy"])
plt.show()

# %%
# Evaluation
from seqeval.metrics import precision_score, recall_score, f1_score, classification_report

test_pred = model.predict(X_te, verbose=1)
d_index_to_tags = {i: w for w, i in d_tags_to_index.items()}

def pred2label(pred):
    out = []
    for pred_i in pred:
        out_i = []
        for p in pred_i:
            p_i = np.argmax(p)
            out_i.append(d_index_to_tags[p_i].replace("PAD", "O"))
        out.append(out_i)
    return out

pred_labels = pred2label(test_pred)
test_labels = pred2label(y_te)
print("F1-score: {:.1%}".format(f1_score(test_labels, pred_labels)))
print(classification_report(test_labels, pred_labels))
# Out:
# 893/893 [==============================] - 2s 3ms/step
# F1-score: 57.7%
#            precision    recall  f1-score   support
#
#   Symptom       0.30      0.23      0.26       107
#      Drug       0.89      0.81      0.85       297
#       ADR       0.53      0.56      0.54       628
#   Finding       0.16      0.09      0.11        35
#   Disease       0.59      0.34      0.43       124
#
# micro avg       0.60      0.56      0.58      1191
# macro avg       0.59      0.56      0.57      1191

# %%
# Trying some predictions
idx = 20
p = model.predict(np.array([X_te[idx]]))
p = np.argmax(p, axis=-1)
true = np.argmax(y_te[idx], -1)
print("{:15}||{:5}||{}".format("Word", "True", "Pred"))
print(30 * "=")
for w, t, pred in zip(X_te[idx], true, p[0]):
    if w != 0:
        print("{:15}: {:5} {}".format(l_words[w-1], l_tags[t], l_tags[pred]))
# Out:
# Word           ||True ||Pred
# ==============================
# Extreme        : O     B-ADR
# diarrhea       : B-ADR B-ADR
# ,              : O     O
# vomiting       : B-ADR B-ADR
# ,              : O     O
# extreme        : B-ADR B-ADR
# sweating       : I-ADR I-ADR
# ,              : O     O
# dizzyness      : B-ADR B-ADR
# ,              : O     O
# very           : B-ADR B-ADR
# weak           : I-ADR I-ADR
# ,              : O     O
# powerful       : O     O
# chills         : B-ADR B-ADR
# but            : O     I-ADR
# no             : O     I-ADR
# fever          : O     I-ADR
# ,              : O     O
# bloody         : O     O
# discharge      : O     O
# 0              : O     O
# antiulcer      : O     O
# antiulcer      : O     O
# antiulcer      : O     O
# antiulcer      : O     O
# antiulcer      : O     O
# antiulcer      : O     O
# antiulcer      : O     O
# antiulcer      : O     O
# antiulcer      : O     O
# antiulcer      : O     O
# antiulcer      : O     O
# antiulcer      : O     O
# antiulcer      : O     O
# antiulcer      : O     O
# antiulcer      : O     O
# antiulcer      : O     O
# antiulcer      : O     O
# antiulcer      : O     O
# antiulcer      : O     O
# antiulcer      : O     O
# antiulcer      : O     O
# antiulcer      : O     O
# antiulcer      : O     O

# %%
# Prediction on new sentence
test_sentence = ["I", "was", "suffering", "with", "chronicle", "headaches", "took",
                 "crocin", "for", "relieving", "pain"]
x_test_sent = pad_sequences(sequences=[[d_words_to_index.get(w, 0) for w in test_sentence]],
                            padding="post", value=0, maxlen=n_max_seq_size)
p = model.predict(np.array([x_test_sent[0]]))
p = np.argmax(p, axis=-1)
print("{:15}:{}".format("Word", "Prediction"))
print("="*26)
for w, pred in zip(test_sentence, p[0]):
    print("{:15}:  {:5}".format(w, l_tags[pred]))
# Out:
# Word           :Prediction
# ==========================
# I              :  O
# was            :  O
# suffering      :  O
# with           :  O
# chronicle      :  B-ADR
# headaches      :  B-ADR
# took           :  O
# crocin         :  B-ADR
# for            :  O
# relieving      :  O
# pain           :  B-Drug
